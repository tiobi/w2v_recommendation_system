# %%
import pandas as pd
import glob
import numpy as np
import nltk
import csv
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer, word_tokenize, sent_tokenize
from gensim.models.word2vec import Word2Vec 
from konlpy.tag import Twitter
import re

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import csv
file_name = "total_robot_team_d2.csv"
f = open(file_name, 'r', encoding = 'utf-8')
data = csv.reader(f)
f.close
next(data)
sns_text = []
for row in data:
    sns_text.append(str(row[-1]))

# %%
# Out:
# ['첫줄\n\nhttps://cafe.naver.com/ysbaby/127931\n\n#연산점#하이마트#세일#전도사#도마#주세요#식기세척기#티비#로봇청소기#에어컨#캐리어#사세요#하이마트로가요',
#  '로봇청소기가 신기한 쿵이!\n로청따라 졸졸졸\n두번째 이사는 좀 금방 적응하는군.\n.\n.\n#이사완료 #로봇청소기 #냥이와로봇청소기',
#  '하나도 안무섭지만 쟤 집에 가면 내려갈게 #명태 #최대의 #적 #로봇청소기 #내고양이 #고양이 #cat #britishshorthair',
#  'X꼬 그루밍 못해서 궁딩이 간지러운 초파\n#초파 #뒹굴 #응가그림 #로봇청소기',
#  'ღ+616ժɑվ,+1377ժɑվ\n⠀\n#안녕👋\n#반가워\n#우리집을부탁해\n#새식구가생겼어요\n#살아남기를🙏🏻\n#장남감아니에요\n⠀\n보자마자 폭풍 애정 😍\n뽀뽀는...하지말자~~!!!⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n#유아슈즈#키즈슈즈#신학기준비#여름신상업뎃중\n👉🏻👉🏻@mutti_muttishoes ⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀\n⠀\n⠀\n#육아스타그램#44개월아기#원숭이띠아들#황금개띠아들🐶#19개월아기#아들스타그램#워킹맘일상#워킹맘그램##형제맘👬#아들만둘#홈스타그램🏠 #집스타그램#로봇청소기#로보락s5max',
#  '#이거뭐냥',
#  '#로봇청소기 #치후360s9 졸귀!! 먼지 다 뒤졌다ㅋㅋㅋ',
# ...

# %%
tokenized_text = []

for lines in sns_text:
    tokenized_text.append(sent_tokenize(str(sns_text)))
    
embedding_model = Word2Vec(tokenized_text, size = 100, window = 2, min_count = 30, workers = 2, iter= 100, sg = 1)

# %%
embedding_model = Word2Vec(tokenized_text, size = 100, window = 2, min_count = 30, workers = 2, iter= 100, sg = 1)

# %%
while 1:
    print("type exit to break\n")
    keyword = input("유사도를 알고싶은 단어를 입력하세요 : ")
    if keyword == "exit": break
    print(embedding_model.wv.most_similar(positive = keyword, topn = 1))

# %%
for string in tokenized_text:
    tokens = re.sub(r"[^a-z0-9]+", " ", string.lower())
    normalized_text.append(tokens)
    
for line in normalized_text:
    malist

# %%
f = open( "filename.here" , 'r' ,encoding = 'utf-8')
data = csv.reader(f)
f.close()
